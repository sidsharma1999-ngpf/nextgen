# %%
import pandas as pd
path = '/Users/sidsharma/Downloads/Users - 20181214160431.csv'
df = pd.read_csv(path)
df = df.drop(df.columns[20:],axis=1)
df['Time'] = df['createDate'].apply(lambda x: x[11:])
df['createDate'] = df['createDate'].apply(lambda x: x[:10])
print(df)
# Out:
#        userID    firstName         lastName  \
# 0           1          NaN              NaN
# 1           2          Tim         Ranzetta
# 2           3          NaN              NaN
# 3           4          NaN              NaN
# 4           5      Jessica  Endlich Winkler
# 5           6        Brian             Shim
# 6           7       Andrew            Furth
# 7           8          NaN              NaN
# 8          20          NaN              NaN
# 9          21          NaN              NaN
# 10         22          NaN              NaN
# 11         23       Amanda             Volz
# 12         24          NaN              NaN
# 13         25          NaN              NaN
# 14         26   Jacqueline          Prester
# 15         27        Jodie        Holmquist
# 16         28         Jill           Lucero
# 17         29          NaN              NaN
# 18         30          NaN              NaN
# 19         31        heidi           Stokar
# ...
