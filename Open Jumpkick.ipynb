# %%
import requests
import pandas as pd
from google.cloud import bigquery

df = pd.read_csv('https://me.jumpkick.info/aaa-cp/api/downloads/get/?key=klasjdklja283798asd908ajklLKJDSLKJASLKJD078a0sdjlkj2307adlKJSADL&key2=23jlkasjdasd0asdlkjas907asd08alskjdLKJLSIKJDa0s7dklasjdklja28379&thisTable=cpUsers&db=nextgenp_main')
#url = 'https://me.jumpkick.info/aaa-content/user/reports/145327sd929a9dk2232324dVjK3434232232523n/145327sd929a9dk2232324dVjK34dfasldl2ladn/advocacy-schools-all.php?showAll=no&download=true&key=klasjdklja283798asd908ajklLKJDSLKJASLKJD078a0sdjlkj2307adlKJSADL&key2=23jlkasjdasd0asdlkjas907asd08alskjdLKJLSIKJDa0s7dklasjdklja28379&thisReport=&db=nextgenp_main'
#values = {'Username': 'sid@nextgenpersonalfinance.org',
         # 'password': 't:%;voxGuXtA6x1mA:|^1.XP5*llBb'}
print(df)

client = bigquery.Client()
dataset_ref = client.dataset('ng-db-234000')
table_ref = dataset_ref.table('new_table')

client.load_table_from_dataframe(df, table_ref).result()
# Out:
#        userID   firstName         lastName  \
# 0           1         NaN              NaN
# 1           2         Tim         Ranzetta
# 2           3         NaN              NaN
# 3           4         NaN              NaN
# 4           5     Jessica  Endlich Winkler
# 5           6       Brian             Shim
# 6           7      Andrew            Furth
# 7           8         NaN              NaN
# 8          20         NaN              NaN
# 9          21         NaN              NaN
# 10         22         NaN              NaN
# 11         23      Amanda             Volz
# 12         24         NaN              NaN
# 13         25         NaN              NaN
# 14         26  Jacqueline          Prester
# 15         27       Jodie        Holmquist
# 16         28        Jill           Lucero
# 17         29         NaN              NaN
# 18         30         NaN              NaN
# 19         31       heidi           Stokar
# 20         32      Angela       Principato
# ...

# %%
# Out:
#   File "<ipython-input-5-e40784b51362>", line 3
#     except:
#            ^
# SyntaxError: unexpected EOF while parsing
